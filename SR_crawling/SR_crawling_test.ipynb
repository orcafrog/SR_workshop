# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from tqdm.notebook import tqdm

import pandas as pd
import time
import re
import csv
import datetime

print('search')
searchQ = input()
print('startYear')
startYear = input()
print('endYear')
endYear = input()

print("start crawling..")

driver = webdriver.Chrome()
#xpath = driver.find_element_by_xpath

#검색
driver.get('https://www.dbpia.co.kr/')
keyword = driver.find_element("id",'searchInput')
keyword.clear()
keyword.send_keys(searchQ)
serach_click_btn = driver.find_element(By.XPATH,'//*[@id="submitSearchInput"]/span')
driver.execute_script("arguments[0].click();",serach_click_btn)

#날짜 지정 및 텍스트 박스 설정
time.sleep(1)
driver.find_element(By.XPATH,'//*[@id="yearRangeMin"]').clear()
driver.find_element(By.XPATH,'//*[@id="yearRangeMin"]').send_keys(startYear)
driver.find_element(By.XPATH,'//*[@id="yearRangeMax"]').clear()
driver.find_element(By.XPATH,'//*[@id="yearRangeMax"]').send_keys(endYear)
click_btn = driver.find_element(By.XPATH,'//*[@id="yearRangeSearch"]')
driver.execute_script("arguments[0].click();",click_btn)

items_source = driver.page_source
bs = BeautifulSoup(items_source, 'html.parser')
items = bs.find_all('article', {'class':'thesis__summary'})
count = len(items)

title_list = []
author_list = []
publisher_list = []
journal_list = []
volume_list = []
date_list = []
abstract_list = []
link_list = []

list_count = 0
want_page = 10

for item in tqdm(items):
    # 제목
    try:
        title = ''
        title = item.find('h2',{'class':'thesis__tit'}).text
    except:
        title = ''
    
    #저자
    try:
        author = ''
        author = item.find('span',{'class':'thesis__author'}).text
    except:
        author = ''
        
    # 퍼블리셔 
    try:
        publisher = ''
        publisher = item.find('section',{'class':'thesisAdditionalInfo thesis__info'}).find('a',{'class':'nodeIprd thesis__item'}).text
    except:
        publisher = ''
    
    # 저널명
    try:
        journal = ''
        journal = item.find('section',{'class':'thesis__info'}).find('span',{'class':'thesis__item'}).text
    except:
        journal = ''
    
    #볼륨
    try:
        volume = ''
        volume = item.find('section',{'class':'thesisAdditionalInfo thesis__info'}).find('a',{'class':'nodeVois thesis__item'}).text
    except:
        volume = ''
    
    #날짜
    try:
        date = ''
        date = item.find('section',{'class':'thesisAdditionalInfo thesis__info'}).find('span',{'class':'thesis__item'}).text
    except:
        date = ''
    
    #초록
    try:
        abstract = ''
        abstract = item.find('span',{'class':'thesis__abstract'}).text
    except:
        abstract = ''
    
    #link
    try:
        link = ''
        link = item.find('a',{'class':'thesis__link title'}).attrs['href']
    except:
        link = ''
    
    title_list.append(title)
    author_list.append(author)
    publisher_list.append(publisher)
    link_list.append('https://www.dbpia.co.kr'+link)
    journal_list.append(journal)
    volume_list.append(volume)
    date_list.append(date)
    abstract_list.append(abstract)

result = pd.DataFrame({'title_list':title_list, 'author_list':author_list, 'publisher_list':publisher_list, 'link_list':link_list,'journal_list':journal_list, 'volume_list': volume_list, 'date_list':date_list, 'abstract_list': abstract_list})
# Out:
# search
# 인공지능
# startYear
# 2000
# endYear
# 2023
# start crawling..
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
result
# Out:
#                                            title_list author_list  \
# 0                                             인공지능과 법
# 1                 인공지능 노출 정도에 따른 고용 추세 분석: K자형 고용 양극화         이예슬
# 2                 인공지능 기술 기반 교육용 도구에 대한 학습자 인식에 관한 연구         한형종
# 3                 전장인식을 위한 인공지능 기반 상황분석 데이터셋 구축 방안 연구         진소연
# 4                         초등학교 인공지능 교육을 위한 게이미피케이션 설계         진영훈
# 5                                 인공지능 시대, 인간 건축가의 영역         추승연
# 6         생성형 인공지능 기술의 핵심 구성 요소 기반 주요 특허 발굴 방법에 관한 연구         김가윤
# 7          웹(앱) 기반 인공지능 응용서비스의 사용자 만족도와 효과성 평가에 관한 연구         문희정
# 8                                            비판적 인공지능         이원재
# 9             특허 동향 분석을 통한 언어 모델 기반 생성형 인공지능 발전 방향 연구         김대희
# 10               인공지능 시대, 서사적 상상력을 활용한 인문 교양 교육 방안 연구         손혜숙
# 11                               인공지능 기반 콩 생장분석 방법 연구         전문석
# 12                                인공지능 시대의 건축: 헤어질 결심         김성아
# 13         젠더 패턴 : 인공지능 성별 인식 기술에 나타난 '젠더' 개념의 비판적 고찰         이정현
# 14   리그 오브 레전드에서 과정 데이터와 설정 데이터를 활용한 실력 분류 인공지능 모델 제작         허민구
# 15  생성형 인공지능 챗봇 챗지피티(ChatGPT) 이용 의도에 대한 연구 : 기술 수용...         유혜리
# 16  지식 그래프와 설명가능 인공지능 기반 사이버 범죄 수사를 위한 지능형 의사결정 지원...         정희영
# 17               질감 분석 및 인공지능 기반 토마토 과실 특징 추정 알고리즘 구현         이정호
# 18                   인공지능 윤리 역량 신장을 위한 인공지능 윤리 딜레마 개발         김은경
# 19  초·중등교육 내 생성형 인공지능 도입을 위한 법률적 이슈 탐색 - 디지털기반 교육혁...         이영호
#
#    publisher_list                                          link_list  \
# 0       한국지식재산연구원  https://www.dbpia.co.kr/journal/articleDetail?...
# 1     한국지능정보사회진흥원  https://www.dbpia.co.kr/journal/articleDetail?...
# 2      한국디지털콘텐츠학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 3       한국컴퓨터정보학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 4          한국게임학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 5          대한건축학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 6    한국정보전자통신기술학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 7      한국디지털콘텐츠학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 8          대한건축학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 9    한국정보전자통신기술학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 10     다빈치미래교양연구소  https://www.dbpia.co.kr/journal/articleDetail?...
# 11       한국산업정보학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 12         대한건축학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 13       한국언론정보학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 14         한국게임학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 15         한국방송학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 16      한국지능시스템학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 17         한국통신학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 18      한국컴퓨터교육학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 19      한국컴퓨터교육학회  https://www.dbpia.co.kr/journal/articleDetail?...
#
#    journal_list volume_list date_list  \
# 0       2019.12               2019.12
# 1        2023.9       30(3)    2023.9
# 2       2023.10      24(10)   2023.10
# 3       2023.10      28(10)   2023.10
# 4       2023.10       23(5)   2023.10
# 5       2023.10      67(11)   2023.10
# 6       2023.10       16(5)   2023.10
# 7       2023.10      24(10)   2023.10
# 8       2023.10      67(11)   2023.10
# 9       2023.10       16(5)   2023.10
# 10      2023.10          25   2023.10
# 11      2023.10       28(5)   2023.10
# 12      2023.10      67(11)   2023.10
# 13      2023.10         121   2023.10
# 14      2023.10       23(5)   2023.10
# 15      2023.10         124   2023.10
# 16       2023.8       33(4)    2023.8
# 17      2023.10      48(10)   2023.10
# 18       2023.9       26(5)    2023.9
# 19       2023.9       26(5)    2023.9
#
#                                         abstract_list
# 0
# 1   특히 인공지능 기술 발전과 고용에 대한 실증 논의는 더욱 부족한 실정이다.  이에 ...
# 2   인공지능 기술 기반의 다양한 교육용 도구들이 개발되고 있지만 실제 활용자인 학습자들...
# 3   인공지능에 기반한 지능형 지휘통체체계는 복잡하고 방대한 전장정보와 전술 데이터들을 ...
# 4   2022 개정 교육과정을 통하여 초등학생들을 대상으로 한 인공지능 교육에 관심이 고...
# 5
# 6   본 논문에서는 생성형 인공지능 관련 특허에서, 기술의 핵심 구성 요소에 기반하여 수...
# 7   본 논문은 주요 웹(앱) 사이트를 대상으로 인공지능 응용서비스 중심으로 한 사용자 ...
# 8
# 9   최근 몇 년 동안 언어 모델 기반의 생성형 인공지능 기술은 눈에 띄게 발전하고 있다...
# 10  다음으로는 인터랙티브 스토리텔링을 차용하여 서사적 상상력을 활용한 인공지능 교육 방...
# 11
# 12
# 13  매일 새로운 데이터가 되먹여지며 거대해지는 인공지능 기술을 경험하면서 산업 담론과 ...
# 14  본 논문에서는 e스포츠 게임인 리그 오브 레전드의 과정과 설정 데이터를 활용하여 경...
# 15  일반 챗봇보다 더 고도화된 자연어처리가 가능한 생성형 인공지능 챗봇의 경우, 이용자...
# 16  현 상황에서 수사관에게 원활한 의사 결정과 필요한 범죄단서 제공에 도움을 주는 사이...
# 17  최근 스마트 온실의 다양한 분야에 인공지능이 적용되고 있지만, 생산량 관리에 영향을...
# 18  인공지능 기술의 빠른 확산으로 인공지능 윤리 문제는 인공지능 전문가만의 문제가 아닌...
# 19  이에 본 연구는 디지털교육 혁신방안에 대한 분석을 토대로 헌법, 초·중등교육법, 지...

# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from tqdm.notebook import tqdm

import pandas as pd
import time
import re
import csv
import datetime

print('search')
searchQ = input()
print('startYear')
startYear = input()
print('endYear')
endYear = input()
print('wantPage')
want_page = int(input())

print("start crawling..")

driver = webdriver.Chrome()
#xpath = driver.find_element_by_xpath

#검색
driver.get('https://www.dbpia.co.kr/')
keyword = driver.find_element("id",'searchInput')
keyword.clear()
keyword.send_keys(searchQ)
serach_click_btn = driver.find_element(By.XPATH,'//*[@id="submitSearchInput"]/span')
driver.execute_script("arguments[0].click();",serach_click_btn)

#날짜 지정 및 텍스트 박스 설정
time.sleep(10)
driver.find_element(By.XPATH,'//*[@id="yearRangeMin"]').clear()
driver.find_element(By.XPATH,'//*[@id="yearRangeMin"]').send_keys(startYear)
driver.find_element(By.XPATH,'//*[@id="yearRangeMax"]').clear()
driver.find_element(By.XPATH,'//*[@id="yearRangeMax"]').send_keys(endYear)
click_btn = driver.find_element(By.XPATH,'//*[@id="yearRangeSearch"]')
driver.execute_script("arguments[0].click();",click_btn)

items_source = driver.page_source
bs = BeautifulSoup(items_source, 'html.parser')
items = bs.find_all('article', {'class':'thesis__summary'})
count = len(items)

title_list = []
author_list = []
publisher_list = []
journal_list = []
volume_list = []
date_list = []
abstract_list = []
link_list = []

list_count = 2

while(True) :
    for item in tqdm(items):
        # 제목
        try:
            title = ''
            title = item.find('h2',{'class':'thesis__tit'}).text
        except:
            title = ''
    
        #저자
        try:
            author = ''
            author = item.find('span',{'class':'thesis__author'}).text
        except:
            author = ''
        
        # 퍼블리셔 
        try:
            publisher = ''
            publisher = item.find('section',{'class':'thesisAdditionalInfo thesis__info'}).find('a',{'class':'nodeIprd thesis__item'}).text
        except:
            publisher = ''
    
        # 저널명
        try:
            journal = ''
            journal = item.find('section',{'class':'thesis__info'}).find('span',{'class':'thesis__item'}).text
        except:
            journal = ''
    
        #볼륨
        try:
            volume = ''
            volume = item.find('section',{'class':'thesisAdditionalInfo thesis__info'}).find('a',{'class':'nodeVois thesis__item'}).text
        except:
            volume = ''
    
        #날짜
        try:
            date = ''
            date = item.find('section',{'class':'thesisAdditionalInfo thesis__info'}).find('span',{'class':'thesis__item'}).text
        except:
            date = ''
    
        #초록
        try:
            abstract = ''
            abstract = item.find('span',{'class':'thesis__abstract'}).text
        except:
            abstract = ''
    
        #link
        try:
            link = ''
            link = item.find('a',{'class':'thesis__link title'}).attrs['href']
        except:
            link = ''
    
        title_list.append(title)
        author_list.append(author)
        publisher_list.append(publisher)
        link_list.append('https://www.dbpia.co.kr'+link)
        journal_list.append(journal)
        volume_list.append(volume)
        date_list.append(date)
        abstract_list.append(abstract)
    
    if(list_count == want_page):
        break
    else:
        list_count += 1
        try:
            time.sleep(10)
            next_click_btn = driver.find_element(By.XPATH,f'//*[@id="pageList"]/a[{list_count-1}]')
            driver.execute_script("arguments[0].click();",next_click_btn)
            items_source = driver.page_source
            bs = BeautifulSoup(items_source, 'html.parser')
            items = bs.find_all('article', {'class':'thesis__summary'})
            count = len(items)
        except Exception as e:
            print(f"error: {e}")
            break
    
    
    #click_btn = driver.find_element(By.XPATH,f'//*[@id="pageList"]/a[{list_count+1}]')
    #driver.execute_script("arguments[0].click();",click_btn)

result = pd.DataFrame({'title_list':title_list, 'author_list':author_list, 'publisher_list':publisher_list, 'link_list':link_list,'journal_list':journal_list, 'volume_list': volume_list, 'date_list':date_list, 'abstract_list': abstract_list})
# Out:
# search
# 인공지능
# startYear
# 2000
# endYear
# 2023
# wantPage
# 10
# start crawling..
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]
#   0%|          | 0/20 [00:00<?, ?it/s]

# %%
result = result.drop_duplicates()
result
# Out:
#                                            title_list author_list  \
# 0                                             인공지능과 법
# 1                 인공지능 노출 정도에 따른 고용 추세 분석: K자형 고용 양극화         이예슬
# 2                 인공지능 기술 기반 교육용 도구에 대한 학습자 인식에 관한 연구         한형종
# 3                 전장인식을 위한 인공지능 기반 상황분석 데이터셋 구축 방안 연구         진소연
# 4                         초등학교 인공지능 교육을 위한 게이미피케이션 설계         진영훈
# ..                                                ...         ...
# 175                      멤리스터 인공지능 칩의 SNN 기반 응용 기술 개발         이왕주
# 176  유럽연합-미국 무역기술위원회(TTC) 공동합의문 발표... 신뢰할 수 있는 인공지능 등
# 177                               ESG 전환 가속화 이끄는 인공지능
# 178            유아를 위한 인공지능(AI) · 소프트웨어(SW) 교육 프로그램 개발         이재은
# 179                국가연구개발투자전략을 위한 인공지능 반도체 기술 및 시장 이슈         원용숙
#
#     publisher_list                                          link_list  \
# 0        한국지식재산연구원  https://www.dbpia.co.kr/journal/articleDetail?...
# 1      한국지능정보사회진흥원  https://www.dbpia.co.kr/journal/articleDetail?...
# 2       한국디지털콘텐츠학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 3        한국컴퓨터정보학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 4           한국게임학회  https://www.dbpia.co.kr/journal/articleDetail?...
# ..             ...                                                ...
# 175        대한전자공학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 176        한국특허신문사  https://www.dbpia.co.kr/journal/articleDetail?...
# 177     한국경제매거진(주)  https://www.dbpia.co.kr/journal/articleDetail?...
# 178     한국어린이미디어학회  https://www.dbpia.co.kr/journal/articleDetail?...
# 179         한국통신학회  https://www.dbpia.co.kr/journal/articleDetail?...
#
#     journal_list volume_list date_list  \
# 0        2019.12               2019.12
# 1         2023.9       30(3)    2023.9
# 2        2023.10      24(10)   2023.10
# 3        2023.10      28(10)   2023.10
# 4        2023.10       23(5)   2023.10
# ..           ...         ...       ...
# 175       2023.6                2023.6
# 176       2023.7         204    2023.7
# 177       2023.7          25    2023.7
# 178       2023.6                2023.6
# 179       2023.6                2023.6
#
#                                          abstract_list
# 0
# 1    특히 인공지능 기술 발전과 고용에 대한 실증 논의는 더욱 부족한 실정이다.  이에 ...
# 2    인공지능 기술 기반의 다양한 교육용 도구들이 개발되고 있지만 실제 활용자인 학습자들...
# 3    인공지능에 기반한 지능형 지휘통체체계는 복잡하고 방대한 전장정보와 전술 데이터들을 ...
# 4    2022 개정 교육과정을 통하여 초등학생들을 대상으로 한 인공지능 교육에 관심이 고...
# ..                                                 ...
# 175
# 176
# 177
# 178  본 연구의 목적은 유아의 디지털 역량을 함양하기 위한 인공지능(AI) · 소프트웨어...
# 179
#
# [160 rows x 8 columns]

# %%
result.to_excel(f'{searchQ}_crawling_data.xlsx', index=False)
